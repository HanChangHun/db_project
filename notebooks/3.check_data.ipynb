# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/haccp_dataset_200525221016.csv")

# %%
set(df['prdkind'])
# Out:
# {'Energy Drinks',
#  'None',
#  '生치즈',
#  '生탁주',
#  '가공두부',
#  '가공두부,유부',
#  '가공두부/유부',
#  '가공두유',
#  '가공버터',
#  '가공소금',
#  '가공식품',
#  '가공식품,라면',
#  '가공우유',
#  '가공유',
#  '가공유크림',
#  '가공치즈',
#  '가공품',
#  '가당연유',
#  '가열 후 섭취 냉동식품',
#  '가열성형제품',
#  '가열양념육',
#  '가열양념육류',
#  '가열하여 섭취하는 냉동식품',
#  '갈비가공품',
#  '갈색설탕',
#  '강정류',
#  '강화우유',
#  '강화저지방우유',
#  '개량한식간장',
#  '건강기능식품',
#  '건면',
#  '건면류',
#  '건면류(국수)/복합조미식품(스프)',
#  '건어포류',
#  '건조',
#  '건조 저장육류',
#  '건조저장육',
#  '건조저장육류',
#  '경성치즈',
#  '고추장',
#  '고춧가루',
#  '고형차',
#  '곡류 가공품',
#  '곡류가공품',
#  '곡류사공품',
#  '곡물가공품',
#  '곡물양조식초',
#  '과 · 채음료',
#  '과 · 채주스',
#  '과 • 채음료',
#  '과 채주스',
#  '과,채음료',
#  '과,채주스',
#  '과.채가공품',
#  '과.채가공품류',
#  '과.채음료',
#  '과.채음료-가열',
#  '과.채음료-비가열',
#  '과.채주스',
#  '과.채주스-가열',
#  '과.채주스-비가열',
#  '과/채음료',
#  '과·채가공품',
#  '과·채가공품류',
#  '과·채음료',
#  '과·채주스',
#  '과자',
#  '과자(기타)',
#  '과자(비스킷류)',
#  '과자(스낵과자)',
#  '과자(스낵과자류)',
#  '과자(유탕처리제품)',
#  '과자,소스류',
#  '과자류',
#  '과자유처리제품',
#  '과제',
#  '과즙음료',
#  '과채가공품',
# ...

# %%
set(df['prdkind'])
# Out:
# {'Energy Drinks',
#  'None',
#  '生치즈',
#  '生탁주',
#  '가공두부',
#  '가공두부,유부',
#  '가공두부/유부',
#  '가공두유',
#  '가공버터',
#  '가공소금',
#  '가공식품',
#  '가공식품,라면',
#  '가공우유',
#  '가공유',
#  '가공유크림',
#  '가공치즈',
#  '가공품',
#  '가당연유',
#  '가열 후 섭취 냉동식품',
#  '가열성형제품',
#  '가열양념육',
#  '가열양념육류',
#  '가열하여 섭취하는 냉동식품',
#  '갈비가공품',
#  '갈색설탕',
#  '강정류',
#  '강화우유',
#  '강화저지방우유',
#  '개량한식간장',
#  '건강기능식품',
#  '건면',
#  '건면류',
#  '건면류(국수)/복합조미식품(스프)',
#  '건어포류',
#  '건조',
#  '건조 저장육류',
#  '건조저장육',
#  '건조저장육류',
#  '경성치즈',
#  '고추장',
#  '고춧가루',
#  '고형차',
#  '곡류 가공품',
#  '곡류가공품',
#  '곡류사공품',
#  '곡물가공품',
#  '곡물양조식초',
#  '과 · 채음료',
#  '과 · 채주스',
#  '과 • 채음료',
#  '과 채주스',
#  '과,채음료',
#  '과,채주스',
#  '과.채가공품',
#  '과.채가공품류',
#  '과.채음료',
#  '과.채음료-가열',
#  '과.채음료-비가열',
#  '과.채주스',
#  '과.채주스-가열',
#  '과.채주스-비가열',
#  '과/채음료',
#  '과·채가공품',
#  '과·채가공품류',
#  '과·채음료',
#  '과·채주스',
#  '과자',
#  '과자(기타)',
#  '과자(비스킷류)',
#  '과자(스낵과자)',
#  '과자(스낵과자류)',
#  '과자(유탕처리제품)',
#  '과자,소스류',
#  '과자류',
#  '과자유처리제품',
#  '과제',
#  '과즙음료',
#  '과채가공품',
# ...

# %%
len(set(df['prdkind']))
# Out:
# 585

# %%
set(df['rawmtrl'])
# Out:
# {'정제수,백설탕,수박농축액(수박즙으로 10%:미국산),구연산,합성착향료(수박향,시트러스향),자주색고구마색소,락색소,비타민C,효소처리루틴',
#  '소맥분(밀:미국,호주산),옥수수전분[옥수수:외국산(러시아,헝가리,세르비아등)],쌀가루(백미:국내산),설탕,정제소금(국내산),마늘분말,양파분말,혼합제제(팽창제,탄산수소나트륨,소맥분),치자황색소',
#  '쇠고기진육48.48%{다시마추출액[정제수,다시마(국산),한우(국산)20%},덱스트린,새송이버섯(국산)6.23%,감자(국산)6.23%,시금치(국산)6.23%,당근(국산)6.23%,양배추(국산)6.23%,감자전분.',
#  '백설탕,물엿,연유4%,전지분유(우유,국산)1.5%,생크림(우유)0.5%,산도조절제,딸기농축과실즙0.22%(딸기과실즙으로2%)(국산),합성착향료(딸기향,밀크향),혼합제제{코치닐추출색소,Shade Strawberry red P(적양배추색소,엘더베리색소,설탕,산도조절제),프로필렌글리콜,비타민C}',
#  '초코칩핫케익가루92%[밀가루(밀:미국산),백설탕,식물성쇼트닝{팜유(말레이시아산),d-토코페롤(혼합형)},옥수수전분,코코아분말,유청분말,포도당,베이킹파우더(산도조절제,전분,유화제),정제소금,덱스트린,혼합제제(바닐린,포도당),유화제],초코칩(캐나다산,백설탕,부분경화팜핵유,코코아,덱스트로스,레시틴)',
#  '닭고기26.25%,돼지고기24.13%',
# ...
